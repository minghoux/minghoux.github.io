# %% [markdown]
# Following youtube video:
# https://www.youtube.com/watch?v=HW29067qVWk&t=209s

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.randn(10,5))
df.head()
# Out:
#           0         1         2         3         4
# 0 -0.017892  1.101385 -0.175538  0.992394  0.001061
# 1  1.217805 -0.452630  0.238171 -1.529545 -1.172271
# 2 -1.188771 -0.863190 -0.302329  0.216466  1.171507
# 3 -0.807805  0.091648 -0.075652  1.951833  0.323005
# 4  0.049573  1.371446 -1.068320  1.345847 -0.743403

# %%
import numpy as np
import matplotlib.pyplot as plt

N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N))**2

plt.scatter(x,y,s=area, c=colors, alpha=0.5)
plt.show()
